# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# [Pandas](https://pandas.pydata.org/) is a data analysis library in Python. It is generally used along with [Matplotlib](https://matplotlib.org/) for visualizations and [NumPy](http://www.numpy.org/) which is used for scientific computations. Pandas is inspired from [R's Data Frame](http://www.r-tutor.com/r-introduction/data-frame)
#
# **Note:** This notebook assume we're using Python 3

# %% [markdown]
# ## Loading some data and doing some basic operations

# %%
import pandas as pd # this is called aliasing
print(pd.__version__)

pd.read_csv("./data/gapminder.tsv", delimiter="\t")
# Out:
# 0.21.0
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
df = pd.read_csv("./data/gapminder.tsv", delimiter="\t")

# .head() shows you first 5 rows
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# .shape is what tells what dimension the data frame is {row x columns}
# .shape is attribute and not method
df.shape
# Out:
# (1704, 6)

# %%
# .info() tell you more about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ## Selecting subset{s} of your Data Frame

# %%
country_df = df['country'] # selects the columns

# %%
df.country # alternative approach
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
# this is how multiple columns are done
df[['country', 'continent', 'year']].head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
# this will get you list of columns
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
# deleting a column can be achieved this way
# df.drop() is another way you can use for achieving same thing
del df['country']
df.head()
# Out:
#   continent  year  lifeExp       pop   gdpPercap
# 0      Asia  1952   28.801   8425333  779.445314
# 1      Asia  1957   30.332   9240934  820.853030
# 2      Asia  1962   31.997  10267083  853.100710
# 3      Asia  1967   34.020  11537966  836.197138
# 4      Asia  1972   36.088  13079460  739.981106

# %%
# Reload data again
df = pd.read_csv("./data/gapminder.tsv", delimiter="\t")

#subseting rows
# 1. loc attribute {negative indexing doesn't work}
# 0 is "label" you can custom define those
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
# 2. iloc attribute {allows negative indexing}
# iloc - stands for index location
df.iloc[-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
# this is how you subset list of rows
df.iloc[[0, 9, 99]]
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351
# 99   Bangladesh      Asia  1967   43.453  62821884  721.186086

# %%
# this is how you can subset both in column and row dimension
# {iloc doesnt work}
df.loc[[0, 9, 99], ['country', 'year']]
# Out:
#         country  year
# 0   Afghanistan  1952
# 9   Afghanistan  1997
# 99   Bangladesh  1967

# %%
# each column become what is called "Series"
# each of them have a method
le_mean = df[['lifeExp']].mean()
le_mean
# Out:
# lifeExp    59.474439
# dtype: float64

# %%
# this is for groupby data on dataset {create partition, merge groups}
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')['lifeExp', 'gdpPercap'].mean()
# Out:
#         lifeExp     gdpPercap
# year
# 1952  49.057620   3725.276046
# 1957  51.507401   4299.408345
# 1962  53.609249   4725.812342
# 1967  55.678290   5483.653047
# 1972  57.647386   6770.082815
# 1977  59.570157   7313.166421
# 1982  61.533197   7518.901673
# 1987  63.212613   7900.920218
# 1992  64.160338   8158.608521
# 1997  65.014676   9090.175363
# 2002  65.694923   9917.848365
# 2007  67.007423  11680.071820

# %%
df.groupby(['year', 'continent'])['lifeExp', 'gdpPercap'].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
# count how many unique countries we have per continent
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt

gyle = df.groupby('year')['lifeExp'].mean()
gyle.plot()

# %%
# this will make the dataset flatten
(df.groupby(['year', 'continent'])['lifeExp', 'gdpPercap'].mean()).reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %%
# this is how intermediate data can be saved to csv
some_analysis = (df.groupby(['year', 'continent'])['lifeExp', 'gdpPercap'].mean()).reset_index()
some_analysis.to_csv("some_analysis.csv")
